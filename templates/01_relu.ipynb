# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/01_relu.ipynb)
#
# # 🟢 Easy: Implement ReLU
#
# Implement the **ReLU** (Rectified Linear Unit) activation function from scratch.
#
# $$\text{ReLU}(x) = \max(0, x)$$
#
# ### Signature
# ```python
# def relu(x: torch.Tensor) -> torch.Tensor:
#     ...
# ```
#
# ### Rules
# - Do **NOT** use `torch.relu`, `F.relu`, `torch.clamp`, or any built-in activation
# - Must support autograd (gradients should flow back)
#
# ### Example
# ```
# Input:  tensor([-2., -1., 0., 1., 2.])
# Output: tensor([ 0.,  0., 0., 1., 2.])
# ```

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 3.5 MB/s eta 0:00:00

# %%
import torch

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def relu(x: torch.Tensor) -> torch.Tensor:
    # return torch.maximum(x, torch.zeros_like(x)) # elementwise max fails gradeint 
    return (x>0).float() * x # works because 0*0=0 and 1*x=x

# %%
# 🧪 Test your implementation (feel free to add more debug prints)
x = torch.tensor([-2., -1., 0., 1., 2.])
print("Input: ", x)
print("Output:", relu(x))
print("Shape: ", relu(x).shape)
# Out:
# Input:  tensor([-2., -1.,  0.,  1.,  2.])
# Output: tensor([-0., -0., 0., 1., 2.])
# Shape:  torch.Size([5])

# %%
# ✅ SUBMIT — Run this cell to check your solution
from torch_judge import check, hint, status
check("relu")
# Out:
# 🧪 Testing: Implement ReLU (Easy)
# ──────────────────────────────────────────────────
#   ✅ [1/4] Basic values (1.0ms)
#   ✅ [2/4] 2-D tensor (0.6ms)
#   ✅ [3/4] Gradient check (2.3ms)
#   ✅ [4/4] Performance (758.6ms)
# ──────────────────────────────────────────────────
#   🎉 All 4 tests passed! (762.5ms total)
#   Progress saved. Run status() to see your dashboard.

# %%
status()
# Out:
# ────────────────────────────────────────────────────────
#   🔥 TorchCode Progress: 1/40 solved
# ────────────────────────────────────────────────────────
#   ⏳ cross_entropy        [Easy]
#      Cross-Entropy Loss
#   ⏳ dropout              [Easy]
#      Implement Dropout
#   ⏳ embedding            [Easy]
#      Embedding Layer
#   ⏳ gelu                 [Easy]
#      GELU Activation
#   ⏳ gradient_accumulation [Easy]
#      Gradient Accumulation
#   ⏳ gradient_clipping    [Easy]
#      Gradient Norm Clipping
#   ✅ relu                 [Easy]  ⚡ 762.5ms  (4 attempts)
#      Implement ReLU
#   ⏳ softmax              [Easy]
#      Implement Softmax
#   ⏳ weight_init          [Easy]
#      Kaiming Initialization
#   ⏳ adam                 [Medium]
#      Adam Optimizer
#   ⏳ batchnorm            [Medium]
#      Implement BatchNorm
#   ⏳ beam_search          [Medium]
#      Beam Search Decoding
#   ⏳ conv2d               [Medium]
#      2D Convolution
#   ⏳ cosine_lr            [Medium]
#      Cosine LR Scheduler with Warmup
#   ⏳ cross_attention      [Medium]
#      Multi-Head Cross-Attention
#   ⏳ layernorm            [Medium]
#      Implement LayerNorm
#   ⏳ linear               [Medium]
#      Simple Linear Layer
#   ⏳ linear_regression    [Medium]
#      Linear Regression
#   ⏳ lora                 [Medium]
#      LoRA (Low-Rank Adaptation)
#   ⏳ mlp                  [Medium]
#      SwiGLU MLP
#   ⏳ rmsnorm              [Medium]
#      Implement RMSNorm
#   ⏳ topk_sampling        [Medium]
#      Top-k / Top-p Sampling
#   ⏳ vit_patch            [Medium]
#      ViT Patch Embedding
#   ⏳ attention            [Hard]
#      Softmax Attention
#   ⏳ bpe                  [Hard]
#      Byte-Pair Encoding (BPE)
#   ⏳ causal_attention     [Hard]
#      Causal Self-Attention
#   ⏳ dpo_loss             [Hard]
#      DPO (Direct Preference Optimization) Loss
#   ⏳ flash_attention      [Hard]
#      Flash Attention (Tiled)
#   ⏳ gpt2_block           [Hard]
#      GPT-2 Transformer Block
#   ⏳ gqa                  [Hard]
#      Grouped Query Attention
#   ⏳ grpo_loss            [Hard]
#      GRPO (Group Relative Policy Optimization) Loss
#   ⏳ int8_quantization    [Hard]
#      INT8 Quantized Linear
#   ⏳ kv_cache             [Hard]
#      KV Cache Attention
#   ⏳ linear_attention     [Hard]
#      Linear Self-Attention
#   ⏳ mha                  [Hard]
#      Multi-Head Attention
#   ⏳ moe                  [Hard]
#      Mixture of Experts (MoE)
#   ⏳ ppo_loss             [Hard]
#      PPO (Proximal Policy Optimization) Clipped Loss
#   ⏳ rope                 [Hard]
#      Rotary Position Embedding (RoPE)
#   ⏳ sliding_window       [Hard]
#      Sliding Window Attention
#   ⏳ speculative_decoding [Hard]
#      Speculative Decoding
# ────────────────────────────────────────────────────────

# %%
hint('relu')
# Out:
# 💡 Hint for Implement ReLU:
#    ReLU(x) = max(0, x). Think about element-wise comparison with zero.
